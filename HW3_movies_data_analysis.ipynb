# %% [markdown]
# <a href="https://colab.research.google.com/github/PrelaunchZeus2/Data-219/blob/main/HW3_movies_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the numpy and pandas packages
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Step 0: Load the dataset in the working folder

# %%
# Unzip the zip file containing the data. Be sure to specify the correct path to the zip file
# The path below is specific to my own Google Drive.
# !unzip /content/drive/MyDrive/colab/movies_data.zip
# Out:
# Archive:  /content/drive/MyDrive/colab/movies_data.zip
# replace MovieAssignmentData.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: MovieAssignmentData.csv

# %%
# list the contents of the Present Working Directory (also called pwd)
# !ls
# Out:
# drive  MovieAssignmentData.csv	sample_data

# %% [markdown]
# # Step 1: Reading and Inspection
#
#
#
# ### Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.DataFrame(pd.read_csv("./MovieAssignmentData.csv")) # pd.read_csv function is used to read the data
movies.head() # notice the use of the .head() function for quickly displaying the data to get a feel
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Row, columns in the Data
movies.shape
# Out:
# (5043, 28)

# %%
# Concise summary of the Dataframe.
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
#  13  cast_total_facebook_likes  5043 non-null   int64
#  14  actor_3_name               5020 non-null   object
#  15  facenumber_in_poster       5030 non-null   float64
#  16  plot_keywords              4890 non-null   object
#  17  movie_imdb_link            5043 non-null   object
#  18  num_user_for_reviews       5022 non-null   float64
#  19  language                   5031 non-null   object
#  20  country                    5038 non-null   object
#  21  content_rating             4740 non-null   object
#  22  budget                     4551 non-null   float64
#  23  title_year                 4935 non-null   float64
#  24  actor_2_facebook_likes     5030 non-null   float64
#  25  imdb_score                 5043 non-null   float64
#  26  aspect_ratio               4714 non-null   float64
#  27  movie_facebook_likes       5043 non-null   int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# **How many null values does the column with gross budget of the movie (by the name `gross`) have?** [5]

# %%
# Generate descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution,
# excluding NaN values
movies.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                133.000000              614.000000  5.340988e+06
# 50%                371.500000              988.000000  2.551750e+07
# 75%                636.000000            11000.000000  6.230944e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     5.043000e+03                5043.000000           5030.000000
# mean      8.366816e+04                9699.063851              1.371173
# std       1.384853e+05               18163.799124              2.013576
# min       5.000000e+00                   0.000000              0.000000
# 25%       8.593500e+03                1411.000000              0.000000
# 50%       3.435900e+04                3090.000000              1.000000
# 75%       9.630900e+04               13756.500000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           5022.000000  4.551000e+03  4935.000000
# mean             272.770808  3.975262e+07  2002.470517
# std              377.982886  2.061149e+08    12.474599
# min                1.000000  2.180000e+02  1916.000000
# 25%               65.000000  6.000000e+06  1999.000000
# 50%              156.000000  2.000000e+07  2005.000000
# 75%              326.000000  4.500000e+07  2011.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             5030.000000  5043.000000   4714.000000           5043.000000
# mean              1651.754473     6.442138      2.220403           7525.964505
# std               4042.438863     1.125116      1.385113          19320.445110
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                281.000000     5.800000      1.850000              0.000000
# 50%                595.000000     6.600000      2.350000            166.000000
# 75%                918.000000     7.200000      2.350000           3000.000000
# max             137000.000000     9.500000     16.000000         349000.000000

# %% [markdown]
# **What is the longest duration of any movie in the dataset?** [5]

# %%
movies.duration.describe()
# Out:
# count    5028.000000
# mean      107.201074
# std        25.197441
# min         7.000000
# 25%        93.000000
# 50%       103.000000
# 75%       118.000000
# max       511.000000
# Name: duration, dtype: float64

# %% [markdown]
# **How many directors are there?** [5]

# %%
# TODO [1 line]: Write code to find how many different movie genres there are [10]
movies.genres.describe()
# Out:
# count      5043
# unique      914
# top       Drama
# freq        236
# Name: genres, dtype: object

# %% [markdown]
# **How many different movie genres are there?** [5]

# %%
# TODO [1 line]: Write code to find number of languages across all the movies in the dataset [10]
movies.language.describe()
# Out:
# count        5031
# unique         47
# top       English
# freq         4704
# Name: language, dtype: object

# %% [markdown]
# **What is the number of different languages for the movies in the dataset?** [5]

# %% [markdown]
# # Step 2: Cleaning the Data
#
# ### Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column.

# %%
# Code for column-wise null count here
null_value_count = movies.isnull().sum()
null_value_count
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# TODO [1 line]: Write your code for row-wise null count here;
# Use the .sum() function, paying attention to the axis argument [10]
movies.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# TODO [1-2 lines]: Write your code for column-wise null percentages here rounded to 2 decimal places [10]
total_values = movies.count() + null_value_count
missing_percent = (null_value_count / total_values) * 100
print(round(missing_percent, 2))
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.24
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# movie_facebook_likes          0.00
# dtype: float64

# %% [markdown]
# ### Fill NaN values
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# TODO [2 lines]: Fill the NaN values in the 'language' column here with 'English'; use the .fillna() function [20]
movies.language = movies.language.fillna(value = 'English')

# %%
movies.language.isnull().sum() # this should print 0 if your code above is correct
# Out:
# 0

# %% [markdown]
# ### Drop unecessary rows
# Some of the rows might have greater than five NaN values. Such rows aren't of much use for the analysis and hence, we can safely remove them

# %%
# TODO [1 line]: Write your code for dropping these rows here that have > 5 NaN values [10]
movies_na_dropped = movies.dropna(thresh=movies.shape[1] - 5)

# %% [markdown]
# ### Check the number of retained rows
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# TODO [1 line]: Write your code for checking the fraction of retained rows here [10]
fraction_retained = movies_na_dropped.shape[0] / movies.shape[0]
fraction_retained
# Out:
# 1.0

# %% [markdown]
# ### Count duplicate data entries
# Count the number of duplicate rows. Use the `.drop_diplicates()` function of pandas

# %%
len(movies)-len(movies.drop_duplicates())
# Out:
# 0

# %%
# TODO [1 line]: Write your code for dropping duplicate values here [10]
movies = movies.drop_duplicates()

# %% [markdown]
# # Step 3: Data Analysis
#
# ### Find the movies with highest profit
#
# - Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
# - Sort the dataframe using the `profit` column as reference.
# - Extract the top ten profiting movies in descending order and store them in a new dataframe called `top10`

# %%
# TODO [1 line]: Write your code for creating the profit column here [10]
movies = movies.assign(Profit =lambda x: x.gross - x.budget)
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5037  Color       Edward Burns                    14.0      95.0
# 5038  Color        Scott Smith                     1.0      87.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                         0.0                   855.0    Joel David Moore
# 1                       563.0                  1000.0       Orlando Bloom
# 2                         0.0                   161.0        Rory Kinnear
# 3                     22000.0                 23000.0      Christian Bale
# 5                       475.0                   530.0     Samantha Morton
# ...                       ...                     ...                 ...
# 5037                      0.0                   133.0  Caitlin FitzGerald
# 5038                      2.0                   318.0       Daphne Zuniga
# 5040                      0.0                     0.0       Maxwell Moody
# 5041                      0.0                   489.0       Daniel Henney
# 5042                     16.0                    16.0    Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 5                      640.0   73058679.0          Action|Adventure|Sci-Fi
# ...                      ...          ...                              ...
# 5037                   296.0       4584.0                     Comedy|Drama
# 5038                   637.0          NaN                     Comedy|Drama
# 5040                     0.0          NaN            Drama|Horror|Thriller
# 5041                   946.0      10443.0             Comedy|Drama|Romance
# 5042                    86.0      85222.0                      Documentary
#
#       ... language country  content_rating       budget title_year  \
# 0     ...  English     USA           PG-13  237000000.0     2009.0
# 1     ...  English     USA           PG-13  300000000.0     2007.0
# 2     ...  English      UK           PG-13  245000000.0     2015.0
# 3     ...  English     USA           PG-13  250000000.0     2012.0
# 5     ...  English     USA           PG-13  263700000.0     2012.0
# ...   ...      ...     ...             ...          ...        ...
# 5037  ...  English     USA       Not Rated       9000.0     2011.0
# 5038  ...  English  Canada             NaN          NaN     2013.0
# 5040  ...  English     USA             NaN       1400.0     2013.0
# 5041  ...  English     USA           PG-13          NaN     2012.0
# 5042  ...  English     USA              PG       1100.0     2004.0
#
#       actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes  \
# 0                      936.0        7.9         1.78                 33000
# 1                     5000.0        7.1         2.35                     0
# 2                      393.0        6.8         2.35                 85000
# 3                    23000.0        8.5         2.35                164000
# 5                      632.0        6.6         2.35                 24000
# ...                      ...        ...          ...                   ...
# 5037                   205.0        6.4          NaN                   413
# 5038                   470.0        7.7          NaN                    84
# 5040                     0.0        6.3          NaN                    16
# 5041                   719.0        6.3         2.35                   660
# 5042                    23.0        6.6         1.85                   456
#
#            Profit
# 0     523505847.0
# 1       9404152.0
# 2     -44925825.0
# 3     198130642.0
# 5    -190641321.0
# ...           ...
# 5037      -4416.0
# 5038          NaN
# 5040          NaN
# 5041          NaN
# 5042      84122.0
#
# [4857 rows x 29 columns]

# %%
# TODO [1 line]: Write your code for sorting the dataframe here [10]
movies_by_profit = movies.sort_values('Profit', ascending = False)
movies_by_profit
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 0     Color     James Cameron                   723.0     178.0
# 29    Color   Colin Trevorrow                   644.0     124.0
# 26    Color     James Cameron                   315.0     194.0
# 3024  Color      George Lucas                   282.0     125.0
# 3080  Color  Steven Spielberg                   215.0     120.0
# ...     ...               ...                     ...       ...
# 5032  Color   Ash Baron-Cohen                    10.0      98.0
# 5036  Color   Anthony Vallone                     NaN      84.0
# 5038  Color       Scott Smith                     1.0      87.0
# 5040  Color  Benjamin Roberds                    13.0      76.0
# 5041  Color       Daniel Hsia                    14.0     100.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 29                      365.0                  1000.0         Judy Greer
# 26                        0.0                   794.0       Kate Winslet
# 3024                      0.0                   504.0      Peter Cushing
# 3080                  14000.0                   548.0        Dee Wallace
# ...                       ...                     ...                ...
# 5032                      3.0                   152.0  Stanley B. Herman
# 5036                      2.0                     2.0     John Considine
# 5038                      2.0                   318.0      Daphne Zuniga
# 5040                      0.0                     0.0      Maxwell Moody
# 5041                      0.0                   489.0      Daniel Henney
#
#       actor_1_facebook_likes        gross                            genres  \
# 0                     1000.0  760505847.0   Action|Adventure|Fantasy|Sci-Fi
# 29                    3000.0  652177271.0  Action|Adventure|Sci-Fi|Thriller
# 26                   29000.0  658672302.0                     Drama|Romance
# 3024                 11000.0  460935665.0   Action|Adventure|Fantasy|Sci-Fi
# 3080                   861.0  434949459.0                     Family|Sci-Fi
# ...                      ...          ...                               ...
# 5032                   789.0          NaN                       Crime|Drama
# 5036                    45.0          NaN                       Crime|Drama
# 5038                   637.0          NaN                      Comedy|Drama
# 5040                     0.0          NaN             Drama|Horror|Thriller
# 5041                   946.0      10443.0              Comedy|Drama|Romance
#
#       ... language country  content_rating       budget title_year  \
# 0     ...  English     USA           PG-13  237000000.0     2009.0
# 29    ...  English     USA           PG-13  150000000.0     2015.0
# 26    ...  English     USA           PG-13  200000000.0     1997.0
# 3024  ...  English     USA              PG   11000000.0     1977.0
# 3080  ...  English     USA              PG   10500000.0     1982.0
# ...   ...      ...     ...             ...          ...        ...
# 5032  ...  English     USA             NaN          NaN     1995.0
# 5036  ...  English     USA           PG-13       3250.0     2005.0
# 5038  ...  English  Canada             NaN          NaN     2013.0
# 5040  ...  English     USA             NaN       1400.0     2013.0
# 5041  ...  English     USA           PG-13          NaN     2012.0
#
#       actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes  \
# 0                      936.0        7.9         1.78                 33000
# 29                    2000.0        7.0         2.00                150000
# 26                   14000.0        7.7         2.35                 26000
# 3024                  1000.0        8.7         2.35                 33000
# 3080                   725.0        7.9         1.85                 34000
# ...                      ...        ...          ...                   ...
# 5032                   194.0        6.4          NaN                    20
# 5036                    44.0        7.8          NaN                     4
# 5038                   470.0        7.7          NaN                    84
# 5040                     0.0        6.3          NaN                    16
# 5041                   719.0        6.3         2.35                   660
#
#            Profit
# 0     523505847.0
# 29    502177271.0
# 26    458672302.0
# 3024  449935665.0
# 3080  424449459.0
# ...           ...
# 5032          NaN
# 5036          NaN
# 5038          NaN
# 5040          NaN
# 5041          NaN
#
# [4857 rows x 29 columns]

# %%
# print the top 10 movies data
top10 = movies_by_profit.head(10)
top10
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 29    Color    Colin Trevorrow                   644.0     124.0
# 26    Color      James Cameron                   315.0     194.0
# 3024  Color       George Lucas                   282.0     125.0
# 3080  Color   Steven Spielberg                   215.0     120.0
# 17    Color        Joss Whedon                   703.0     173.0
# 509   Color       Roger Allers                   186.0      73.0
# 240   Color       George Lucas                   320.0     136.0
# 66    Color  Christopher Nolan                   645.0     152.0
# 439   Color          Gary Ross                   673.0     142.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 29                      365.0                  1000.0         Judy Greer
# 26                        0.0                   794.0       Kate Winslet
# 3024                      0.0                   504.0      Peter Cushing
# 3080                  14000.0                   548.0        Dee Wallace
# 17                        0.0                 19000.0  Robert Downey Jr.
# 509                      28.0                   847.0        Nathan Lane
# 240                       0.0                  1000.0        Liam Neeson
# 66                    22000.0                 11000.0       Heath Ledger
# 439                     378.0                   575.0    Josh Hutcherson
#
#       actor_1_facebook_likes        gross  \
# 0                     1000.0  760505847.0
# 29                    3000.0  652177271.0
# 26                   29000.0  658672302.0
# 3024                 11000.0  460935665.0
# 3080                   861.0  434949459.0
# 17                   26000.0  623279547.0
# 509                   2000.0  422783777.0
# 240                  20000.0  474544677.0
# 66                   23000.0  533316061.0
# 439                  34000.0  407999255.0
#
#                                         genres  ... language country  \
# 0              Action|Adventure|Fantasy|Sci-Fi  ...  English     USA
# 29            Action|Adventure|Sci-Fi|Thriller  ...  English     USA
# 26                               Drama|Romance  ...  English     USA
# 3024           Action|Adventure|Fantasy|Sci-Fi  ...  English     USA
# 3080                             Family|Sci-Fi  ...  English     USA
# 17                     Action|Adventure|Sci-Fi  ...  English     USA
# 509   Adventure|Animation|Drama|Family|Musical  ...  English     USA
# 240            Action|Adventure|Fantasy|Sci-Fi  ...  English     USA
# 66                 Action|Crime|Drama|Thriller  ...  English     USA
# 439            Adventure|Drama|Sci-Fi|Thriller  ...  English     USA
#
#       content_rating       budget title_year  actor_2_facebook_likes  \
# 0              PG-13  237000000.0     2009.0                   936.0
# 29             PG-13  150000000.0     2015.0                  2000.0
# 26             PG-13  200000000.0     1997.0                 14000.0
# 3024              PG   11000000.0     1977.0                  1000.0
# 3080              PG   10500000.0     1982.0                   725.0
# 17             PG-13  220000000.0     2012.0                 21000.0
# 509                G   45000000.0     1994.0                   886.0
# 240               PG  115000000.0     1999.0                 14000.0
# 66             PG-13  185000000.0     2008.0                 13000.0
# 439            PG-13   78000000.0     2012.0                 14000.0
#
#      imdb_score aspect_ratio  movie_facebook_likes       Profit
# 0           7.9         1.78                 33000  523505847.0
# 29          7.0         2.00                150000  502177271.0
# 26          7.7         2.35                 26000  458672302.0
# 3024        8.7         2.35                 33000  449935665.0
# 3080        7.9         1.85                 34000  424449459.0
# 17          8.1         1.85                123000  403279547.0
# 509         8.5         1.66                 17000  377783777.0
# 240         6.5         2.35                 13000  359544677.0
# 66          9.0         2.35                 37000  348316061.0
# 439         7.3         2.35                140000  329999255.0
#
# [10 rows x 29 columns]

# %% [markdown]
# ### Find IMDb Top 250 Movies
#
# - Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Ensure that for each of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.

# %%
# TODO [3 lines]: Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe
# and name that dataframe as 'IMDb_Top_250' [30]
IMDb_Top_250 = movies.sort_values(by = 'imdb_score', ascending = False).head(250)

# %%
# print a sample of the dataset
IMDb_Top_250
# Out:
#                  color         director_name  num_critic_for_reviews  \
# 1937             Color        Frank Darabont                   199.0
# 3466             Color  Francis Ford Coppola                   208.0
# 2824             Color                   NaN                    53.0
# 3207             Color                   NaN                    53.0
# 66               Color     Christopher Nolan                   645.0
# ...                ...                   ...                     ...
# 4261   Black and White         Robert Rossen                   100.0
# 2944   Black and White       Martin Campbell                   400.0
# 1868             Color        Barry Levinson                   100.0
# 2884             Color       Stephen Chbosky                   364.0
# 2762             Color           Danny Boyle                   418.0
#
#       duration  director_facebook_likes  actor_3_facebook_likes  \
# 1937     142.0                      0.0                   461.0
# 3466     175.0                      0.0                  3000.0
# 2824      55.0                      NaN                     2.0
# 3207      55.0                      NaN                     2.0
# 66       152.0                  22000.0                 11000.0
# ...        ...                      ...                     ...
# 4261     134.0                     31.0                   366.0
# 2944     144.0                    258.0                   834.0
# 1868     133.0                    272.0                   628.0
# 2884     102.0                    139.0                   850.0
# 2762     120.0                      0.0                    40.0
#
#          actor_2_name  actor_1_facebook_likes        gross  \
# 1937   Jeffrey DeMunn                 11000.0   28341469.0
# 3466    Marlon Brando                 14000.0  134821952.0
# 2824  Olaf Lubaszenko                    20.0     447093.0
# 3207  Olaf Lubaszenko                    20.0     447093.0
# 66       Heath Ledger                 23000.0  533316061.0
# ...               ...                     ...          ...
# 4261   Jackie Gleason                   654.0          NaN
# 2944   Tobias Menzies                  6000.0  167007184.0
# 1868   Valeria Golino                 10000.0  172825435.0
# 2884      Ezra Miller                  8000.0   17738570.0
# 2762   Saurabh Shukla                   668.0  141319195.0
#
#                            genres  ... language country  content_rating  \
# 1937                  Crime|Drama  ...  English     USA               R
# 3466                  Crime|Drama  ...  English     USA               R
# 2824                        Drama  ...   Polish  Poland           TV-MA
# 3207                        Drama  ...   Polish  Poland           TV-MA
# 66    Action|Crime|Drama|Thriller  ...  English     USA           PG-13
# ...                           ...  ...      ...     ...             ...
# 4261                  Drama|Sport  ...  English     USA         Unrated
# 2944    Action|Adventure|Thriller  ...  English      UK           PG-13
# 1868                        Drama  ...  English     USA               R
# 2884                Drama|Romance  ...  English     USA           PG-13
# 2762                Drama|Romance  ...  English      UK               R
#
#            budget title_year  actor_2_facebook_likes imdb_score aspect_ratio  \
# 1937   25000000.0     1994.0                   745.0        9.3         1.85
# 3466    6000000.0     1972.0                 10000.0        9.2         1.85
# 2824          NaN        NaN                     3.0        9.1         1.33
# 3207          NaN        NaN                     3.0        9.1         1.33
# 66    185000000.0     2008.0                 13000.0        9.0         2.35
# ...           ...        ...                     ...        ...          ...
# 4261    2000000.0     1961.0                   491.0        8.0         2.35
# 2944  150000000.0     2006.0                  1000.0        8.0         2.35
# 1868   25000000.0     1988.0                   898.0        8.0         1.85
# 2884   13000000.0     2012.0                  3000.0        8.0         1.85
# 2762   15000000.0     2008.0                    56.0        8.0         2.35
#
#       movie_facebook_likes       Profit
# 1937                108000    3341469.0
# 3466                 43000  128821952.0
# 2824                     0          NaN
# 3207                     0          NaN
# 66                   37000  348316061.0
# ...                    ...          ...
# 4261                     0          NaN
# 2944                     0   17007184.0
# 1868                 12000  147825435.0
# 2884                131000    4738570.0
# 2762                 13000  126319195.0
#
# [250 rows x 29 columns]

# %% [markdown]
# Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# TODO [1 line]: Write code to do the above  [20]
Top_Foreign_Lang_Film = IMDb_Top_250.drop(IMDb_Top_250[IMDb_Top_250['language'].str.contains('English' , case=False)].index)
Top_Foreign_Lang_Film
# Out:
#                  color                     director_name  \
# 2824             Color                               NaN
# 3207             Color                               NaN
# 4498             Color                      Sergio Leone
# 4747   Black and White                    Akira Kurosawa
# 4029             Color                Fernando Meirelles
# 2373             Color                    Hayao Miyazaki
# 4921             Color                      Majid Majidi
# 4259             Color  Florian Henckel von Donnersmarck
# 3931             Color                        Ron Fricke
# 3870             Color                        Raja Menon
# 2970             Color                 Wolfgang Petersen
# 1298   Black and White                Jean-Pierre Jeunet
# 4105             Color                    Chan-wook Park
# 1329             Color                    S.S. Rajamouli
# 2323             Color                    Hayao Miyazaki
# 4659             Color                    Asghar Farhadi
# 3685             Color           Rakeysh Omprakash Mehra
# 4033             Color                 Thomas Vinterberg
# 2829             Color               Oliver Hirschbiegel
# 2734   Black and White                        Fritz Lang
# 4809             Color                    Ingmar Bergman
# 4000             Color              Juan José Campanella
# 4160             Color                   Rajkumar Hirani
# 3550             Color                  Denis Villeneuve
# 2047             Color                    Hayao Miyazaki
# 2551             Color                Guillermo del Toro
# 4585             Color                Joshua Oppenheimer
# 98               Color                      Hideaki Anno
# 3553             Color                      José Padilha
# 3423             Color                   Katsuhiro Ôtomo
# 2830             Color                Alejandro Amenábar
# 4461             Color                 Thomas Vinterberg
# 1061   Black and White                  Andrei Tarkovsky
# 4682             Color               Bernardo Bertolucci
# 4267             Color             Alejandro G. Iñárritu
# 2914             Color                       Je-kyu Kang
# 4348             Color                    Jehane Noujaim
# 4912   Black and White               Carl Theodor Dreyer
# 4284             Color                        Ari Folman
# 4664   Black and White               Georg Wilhelm Pabst
#
#       num_critic_for_reviews  duration  director_facebook_likes  \
# 2824                    53.0      55.0                      NaN
# 3207                    53.0      55.0                      NaN
# 4498                   181.0     142.0                      0.0
# 4747                   153.0     202.0                      0.0
# 4029                   214.0     135.0                    353.0
# 2373                   246.0     125.0                   6000.0
# 4921                    46.0      89.0                    373.0
# 4259                   215.0     137.0                    207.0
# 3931                   115.0     102.0                    330.0
# 3870                    39.0     130.0                      6.0
# 2970                    96.0     293.0                    249.0
# 1298                   242.0     122.0                      0.0
# 4105                   305.0     120.0                      0.0
# 1329                    44.0     159.0                     50.0
# 2323                   174.0     134.0                   6000.0
# 4659                   354.0     123.0                      0.0
# 3685                    33.0     157.0                     85.0
# 4033                   349.0     115.0                    346.0
# 2829                   192.0     178.0                    101.0
# 2734                   260.0     145.0                    756.0
# 4809                    76.0      91.0                      0.0
# 4000                   262.0     129.0                    195.0
# 4160                    15.0     144.0                    124.0
# 3550                   226.0     139.0                    777.0
# 2047                   212.0     119.0                   6000.0
# 2551                   406.0     112.0                      0.0
# 4585                   248.0      96.0                     50.0
# 98                       1.0     120.0                     28.0
# 3553                   142.0     115.0                    294.0
# 3423                   150.0     124.0                     78.0
# 2830                   157.0     125.0                    448.0
# 4461                    98.0     105.0                    346.0
# 1061                   144.0     115.0                      0.0
# 4682                   120.0     106.0                    973.0
# 4267                   157.0     115.0                      0.0
# 2914                    86.0     148.0                     16.0
# 4348                    68.0     108.0                     63.0
# 4912                    54.0     126.0                    147.0
# 4284                   231.0      90.0                     56.0
# 4664                    71.0     110.0                     21.0
#
#       actor_3_facebook_likes                  actor_2_name  \
# 2824                     2.0               Olaf Lubaszenko
# 3207                     2.0               Olaf Lubaszenko
# 4498                    24.0                Luigi Pistilli
# 4747                     4.0                 Minoru Chiaki
# 4029                    40.0                     Seu Jorge
# 2373                     7.0              Ryûnosuke Kamiki
# 4921                    27.0        Amir Farrokh Hashemian
# 4259                   155.0                   Ulrich Mühe
# 3931                     0.0  Balinese Tari Legong Dancers
# 3870                    12.0               Sameer Ali Khan
# 2970                    18.0            Martin Semmelrogge
# 1298                    54.0                Jamel Debbouze
# 4105                    38.0                     Ji-tae Yu
# 1329                    72.0                Anushka Shetty
# 2323                   745.0            Jada Pinkett Smith
# 4659                   620.0                  Leila Hatami
# 3685                   199.0             Steven Mackintosh
# 4033                    26.0            Alexandra Rapaport
# 2829                   471.0                    Bruno Ganz
# 2734                    18.0               Gustav Fröhlich
# 4809                    92.0                 Ingrid Thulin
# 4000                    50.0              Soledad Villamil
# 4160                   327.0                   Sanjay Dutt
# 3550                    58.0     Mélissa Désormeaux-Poulin
# 2047                   422.0                 Blythe Danner
# 2551                   250.0                 Maribel Verdú
# 4585                     0.0                   Herman Koto
# 98                      12.0             Shin'ya Tsukamoto
# 3553                    15.0              Fernanda Machado
# 3423                     4.0                 Takeshi Kusao
# 2830                    93.0                   Lola Dueñas
# 4461                   141.0                 Paprika Steen
# 1061                    12.0           Anatoliy Solonitsyn
# 4682                    48.0            Stefania Sandrelli
# 4267                    35.0                 Jorge Salinas
# 2914                   489.0                       Bin Won
# 4348                     5.0                  Ahmed Hassan
# 4912                     0.0              Sylvia Eckhausen
# 4284                     0.0                   Ronny Dayag
# 4664                     3.0               Francis Lederer
#
#       actor_1_facebook_likes       gross  \
# 2824                    20.0    447093.0
# 3207                    20.0    447093.0
# 4498                 16000.0   6100000.0
# 4747                   304.0    269061.0
# 4029                  1000.0   7563397.0
# 2373                    17.0  10049886.0
# 4921                    36.0    925402.0
# 4259                   380.0  11284657.0
# 3931                    48.0   2601847.0
# 3870                    85.0         NaN
# 2970                   362.0  11433134.0
# 1298                   326.0  33201661.0
# 4105                   717.0   2181290.0
# 1329                   218.0   6498000.0
# 2323                   893.0   2298191.0
# 4659                   786.0   7098492.0
# 3685                   397.0   2197331.0
# 4033                    74.0    610968.0
# 2829                   918.0   5501940.0
# 2734                   136.0     26435.0
# 4809                   440.0         NaN
# 4000                   827.0  20167424.0
# 4160                   464.0         NaN
# 3550                   131.0   6857096.0
# 2047                 23000.0   4710455.0
# 2551                   634.0  37623143.0
# 4585                     3.0    484221.0
# 98                     544.0         NaN
# 3553                   585.0      8060.0
# 3423                     6.0    439162.0
# 2830                   273.0   2086345.0
# 4461                   280.0   1647780.0
# 1061                    29.0         NaN
# 4682                   319.0         NaN
# 4267                    85.0   5383834.0
# 2914                   717.0   1110186.0
# 4348                   161.0         NaN
# 4912                     0.0         NaN
# 4284                    56.0   2283276.0
# 4664                   426.0      9950.0
#
#                                                  genres  ...    language  \
# 2824                                              Drama  ...      Polish
# 3207                                              Drama  ...      Polish
# 4498                                            Western  ...     Italian
# 4747                             Action|Adventure|Drama  ...    Japanese
# 4029                                        Crime|Drama  ...  Portuguese
# 2373                 Adventure|Animation|Family|Fantasy  ...    Japanese
# 4921                                       Drama|Family  ...     Persian
# 4259                                     Drama|Thriller  ...      German
# 3931                                  Documentary|Music  ...        None
# 3870                  Action|Drama|History|Thriller|War  ...       Hindi
# 2970                       Adventure|Drama|Thriller|War  ...      German
# 1298                                     Comedy|Romance  ...      French
# 4105                             Drama|Mystery|Thriller  ...      Korean
# 1329                 Action|Adventure|Drama|Fantasy|War  ...      Telugu
# 2323                        Adventure|Animation|Fantasy  ...    Japanese
# 4659                                      Drama|Mystery  ...     Persian
# 3685                       Comedy|Drama|History|Romance  ...       Hindi
# 4033                                              Drama  ...      Danish
# 2829                        Biography|Drama|History|War  ...      German
# 2734                                       Drama|Sci-Fi  ...      German
# 4809                                              Drama  ...     Swedish
# 4000                             Drama|Mystery|Thriller  ...     Spanish
# 4160                               Comedy|Drama|Romance  ...       Hindi
# 3550                                  Drama|Mystery|War  ...      French
# 2047                 Adventure|Animation|Family|Fantasy  ...    Japanese
# 2551                                  Drama|Fantasy|War  ...     Spanish
# 4585                Biography|Crime|Documentary|History  ...  Indonesian
# 98                 Action|Adventure|Drama|Horror|Sci-Fi  ...    Japanese
# 3553                        Action|Crime|Drama|Thriller  ...  Portuguese
# 3423                            Action|Animation|Sci-Fi  ...    Japanese
# 2830                            Biography|Drama|Romance  ...     Spanish
# 4461                                              Drama  ...      Danish
# 1061                               Drama|Mystery|Sci-Fi  ...     Russian
# 4682                                              Drama  ...     Italian
# 4267                                     Drama|Thriller  ...     Spanish
# 2914                                   Action|Drama|War  ...      Korean
# 4348                     Documentary|Drama|History|News  ...      Arabic
# 4912                                      Drama|Fantasy  ...      Danish
# 4284  Animation|Biography|Documentary|Drama|History|War  ...      Hebrew
# 4664                                Crime|Drama|Romance  ...      German
#
#            country  content_rating        budget title_year  \
# 2824        Poland           TV-MA           NaN        NaN
# 3207        Poland           TV-MA           NaN        NaN
# 4498         Italy        Approved  1.200000e+06     1966.0
# 4747         Japan         Unrated  2.000000e+06     1954.0
# 4029        Brazil               R  3.300000e+06     2002.0
# 2373         Japan              PG  1.900000e+07     2001.0
# 4921          Iran              PG  1.800000e+05     1997.0
# 4259       Germany               R  2.000000e+06     2006.0
# 3931           USA           PG-13  4.000000e+06     2011.0
# 3870         India             NaN  4.400000e+06     2016.0
# 2970  West Germany               R  1.400000e+07     1981.0
# 1298        France               R  7.700000e+07     2001.0
# 4105   South Korea               R  3.000000e+06     2003.0
# 1329         India             NaN  1.802615e+07     2015.0
# 2323         Japan           PG-13  2.400000e+09     1997.0
# 4659          Iran           PG-13  5.000000e+05     2011.0
# 3685         India       Not Rated           NaN     2006.0
# 4033       Denmark               R  3.800000e+06     2012.0
# 2829       Germany               R  1.350000e+07     2004.0
# 2734       Germany       Not Rated  6.000000e+06     1927.0
# 4809        Sweden               R  4.000000e+05     1972.0
# 4000     Argentina               R  2.000000e+06     2009.0
# 4160         India           PG-13  1.200000e+08     2006.0
# 3550        Canada               R  6.800000e+06     2010.0
# 2047         Japan              PG  2.400000e+07     2004.0
# 2551         Spain               R  1.350000e+07     2006.0
# 4585            UK       Not Rated  1.000000e+06     2012.0
# 98           Japan             NaN           NaN     2016.0
# 3553        Brazil               R  4.000000e+06     2007.0
# 3423         Japan               R  1.100000e+09     1988.0
# 2830         Spain           PG-13  1.000000e+07     2004.0
# 4461       Denmark               R  1.300000e+06     1998.0
# 1061  Soviet Union              PG  1.000000e+06     1972.0
# 4682         Italy               R  7.500000e+05     1970.0
# 4267        Mexico               R  2.000000e+06     2000.0
# 2914   South Korea               R  1.280000e+07     2004.0
# 4348         Egypt       Not Rated  1.500000e+06     2013.0
# 4912       Denmark       Not Rated           NaN     1955.0
# 4284        Israel               R  1.500000e+06     2008.0
# 4664       Germany       Not Rated           NaN     1929.0
#
#       actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes  \
# 2824                     3.0        9.1         1.33                     0
# 3207                     3.0        9.1         1.33                     0
# 4498                    34.0        8.9         2.35                 20000
# 4747                     8.0        8.7         1.37                 11000
# 4029                    69.0        8.7         1.85                 28000
# 2373                    10.0        8.6         1.85                 28000
# 4921                    35.0        8.5         1.85                     0
# 4259                   284.0        8.5         2.35                 39000
# 3931                     0.0        8.5         2.35                 26000
# 3870                    26.0        8.5         2.35                 10000
# 2970                    21.0        8.4         1.85                 11000
# 1298                   326.0        8.4         2.35                 39000
# 4105                    78.0        8.4         2.35                 43000
# 1329                   133.0        8.4         1.85                 21000
# 2323                   851.0        8.4         1.85                 11000
# 4659                   712.0        8.4         1.85                 48000
# 3685                   227.0        8.4         2.35                     0
# 4033                    69.0        8.3         2.35                 60000
# 2829                   653.0        8.3         1.85                 14000
# 2734                    23.0        8.3         1.33                 12000
# 4809                   132.0        8.2         1.66                     0
# 4000                    88.0        8.2         2.35                 33000
# 4160                   426.0        8.2         2.35                   349
# 3550                    66.0        8.2         1.85                 37000
# 2047                   713.0        8.2         1.85                 13000
# 2551                   269.0        8.2         1.85                 27000
# 4585                     3.0        8.2         1.85                 20000
# 98                     106.0        8.2         2.35                     0
# 3553                    39.0        8.1         1.85                 11000
# 3423                     5.0        8.1         1.85                     0
# 2830                   114.0        8.1         2.35                     0
# 4461                   278.0        8.1         1.33                  5000
# 1061                    29.0        8.1         2.35                     0
# 4682                    90.0        8.1         1.66                     0
# 4267                    79.0        8.1         1.85                 11000
# 2914                   517.0        8.1         2.35                     0
# 4348                    10.0        8.1         1.85                     0
# 4912                     0.0        8.1         1.37                   863
# 4284                     0.0        8.0         1.85                     0
# 4664                    20.0        8.0         1.33                   926
#
#             Profit
# 2824           NaN
# 3207           NaN
# 4498  4.900000e+06
# 4747 -1.730939e+06
# 4029  4.263397e+06
# 2373 -8.950114e+06
# 4921  7.454020e+05
# 4259  9.284657e+06
# 3931 -1.398153e+06
# 3870           NaN
# 2970 -2.566866e+06
# 1298 -4.379834e+07
# 4105 -8.187100e+05
# 1329 -1.152815e+07
# 2323 -2.397702e+09
# 4659  6.598492e+06
# 3685           NaN
# 4033 -3.189032e+06
# 2829 -7.998060e+06
# 2734 -5.973565e+06
# 4809           NaN
# 4000  1.816742e+07
# 4160           NaN
# 3550  5.709600e+04
# 2047 -1.928954e+07
# 2551  2.412314e+07
# 4585 -5.157790e+05
# 98             NaN
# 3553 -3.991940e+06
# 3423 -1.099561e+09
# 2830 -7.913655e+06
# 4461  3.477800e+05
# 1061           NaN
# 4682           NaN
# 4267  3.383834e+06
# 2914 -1.168981e+07
# 4348           NaN
# 4912           NaN
# 4284  7.832760e+05
# 4664           NaN
#
# [40 rows x 29 columns]

# %%
# print the top 5 foreign language films
Top_Foreign_Lang_Film.head(5)
# Out:
#                  color       director_name  num_critic_for_reviews  duration  \
# 2824             Color                 NaN                    53.0      55.0
# 3207             Color                 NaN                    53.0      55.0
# 4498             Color        Sergio Leone                   181.0     142.0
# 4747   Black and White      Akira Kurosawa                   153.0     202.0
# 4029             Color  Fernando Meirelles                   214.0     135.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 2824                      NaN                     2.0  Olaf Lubaszenko
# 3207                      NaN                     2.0  Olaf Lubaszenko
# 4498                      0.0                    24.0   Luigi Pistilli
# 4747                      0.0                     4.0    Minoru Chiaki
# 4029                    353.0                    40.0        Seu Jorge
#
#       actor_1_facebook_likes      gross                  genres  ...  \
# 2824                    20.0   447093.0                   Drama  ...
# 3207                    20.0   447093.0                   Drama  ...
# 4498                 16000.0  6100000.0                 Western  ...
# 4747                   304.0   269061.0  Action|Adventure|Drama  ...
# 4029                  1000.0  7563397.0             Crime|Drama  ...
#
#         language country  content_rating     budget title_year  \
# 2824      Polish  Poland           TV-MA        NaN        NaN
# 3207      Polish  Poland           TV-MA        NaN        NaN
# 4498     Italian   Italy        Approved  1200000.0     1966.0
# 4747    Japanese   Japan         Unrated  2000000.0     1954.0
# 4029  Portuguese  Brazil               R  3300000.0     2002.0
#
#       actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes  \
# 2824                     3.0        9.1         1.33                     0
# 3207                     3.0        9.1         1.33                     0
# 4498                    34.0        8.9         2.35                 20000
# 4747                     8.0        8.7         1.37                 11000
# 4029                    69.0        8.7         1.85                 28000
#
#          Profit
# 2824        NaN
# 3207        NaN
# 4498  4900000.0
# 4747 -1730939.0
# 4029  4263397.0
#
# [5 rows x 29 columns]
